# %%
from youtube_transcript_api import YouTubeTranscriptApi

video_id = "f8dhP521DHI" 
ytt_api = YouTubeTranscriptApi()
transcript_list = ytt_api.fetch(video_id)
# transcript = "/n/n".join(chunk.text for chunk in transcript_list)

# %%
transcript_list
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='So as a final example of divide and conquer, we\xa0\nwill look at a problem called quick select.\n\xa0', start=9.92, duration=6.0), FetchedTranscriptSnippet(text='So selection is the problem of\xa0\nfinding a specific position in\xa0\xa0', start=17.28, duration=4.72), FetchedTranscriptSnippet(text='a list. So in particular we want to find the\xa0\nkth largest value in a sequence of length n.\xa0\xa0', start=22.0, duration=5.76), FetchedTranscriptSnippet(text='So of course one way to do this is to sort the\xa0\nlist in descending order, and then the largest\xa0\xa0', start=28.8, duration=6.16), FetchedTranscriptSnippet(text='value is the first one, the second largest value\xa0\nis the second one and so on, so by just looking at\xa0\xa0', start=34.96, duration=4.48), FetchedTranscriptSnippet(text='position k in the sorted list in descending\xa0\norder we will get the kth largest value.\n\xa0', start=39.44, duration=4.4), FetchedTranscriptSnippet(text='So since we know we can sort in n log n,\xa0\nthis would mean that the kth largest value,\xa0\xa0', start=44.48, duration=5.12), FetchedTranscriptSnippet(text='the selection problem of finding the\xa0\nkth largest value also takes n log n.\xa0\xa0', start=49.6, duration=3.84), FetchedTranscriptSnippet(text='But if we look at some special cases it perhaps\xa0\nsuggests that we could do better. For instance,\xa0\xa0', start=54.8, duration=5.28), FetchedTranscriptSnippet(text='if we want k equal to 1 then we are just\xa0\nlooking for the largest value in the list\xa0\xa0', start=60.08, duration=5.12), FetchedTranscriptSnippet(text='and that is just the maximum. And we know\xa0\nthat we can compute the maximum in a list\xa0\xa0', start=65.2, duration=4.48), FetchedTranscriptSnippet(text='in a single scan so it only takes order\xa0\nn time, it does not take n log n time.\n\xa0', start=69.68, duration=3.68), FetchedTranscriptSnippet(text='Similarly, if k is equal to n, that is, we want\xa0\nthe smallest value in the list, then we can just\xa0\xa0', start=74.16, duration=4.96), FetchedTranscriptSnippet(text='compute the minimum in a single scan of order\xa0\nn. So the question is can we do this for all k?\xa0\xa0', start=79.12, duration=7.04), FetchedTranscriptSnippet(text='So if we fix a k, then of course in\xa0\nthe first pass we can find the largest,\xa0\xa0', start=88.32, duration=4.56), FetchedTranscriptSnippet(text='and then among the remaining in the second\xa0\npass we can find the second largest. \n\xa0', start=93.44, duration=3.6), FetchedTranscriptSnippet(text='So we can make k passes and in order k times n\xa0\ntime, we can always find the kth largest. Now, the\xa0\xa0', start=97.04, duration=5.92), FetchedTranscriptSnippet(text='problem is that as k becomes large, in particular,\xa0\nif k is like n minus 1 or n by 2 for instance,\xa0\xa0', start=102.96, duration=5.6), FetchedTranscriptSnippet(text='then this would become order n squared.\nSo in particular the median is the value in\xa0\xa0', start=108.56, duration=5.12), FetchedTranscriptSnippet(text='the center of the list so if we sort the list then\xa0\nthe median will be the value at position n by 2.\xa0\xa0', start=113.68, duration=5.68), FetchedTranscriptSnippet(text='So if we just use this naive thing here then\xa0\nthe time it will take to find the median\xa0\xa0', start=120.64, duration=6.64), FetchedTranscriptSnippet(text='is n by 2 passes on a list of length\xa0\nn which will be order n squared.\n\xa0', start=127.28, duration=3.76), FetchedTranscriptSnippet(text='Now remember that one thing we had said before is\xa0\nthat if we can actually find the median quickly in\xa0\xa0', start=132.32, duration=5.6), FetchedTranscriptSnippet(text='order n time, then what we can do is we can take\xa0\nthis list and then find the median as the pivot\xa0\xa0', start=137.92, duration=5.92), FetchedTranscriptSnippet(text='and then create this lower list and this upper\xa0\n ...

# %%
from youtube_transcript_api.formatters import TextFormatter, JSONFormatter

# %%
formatter = JSONFormatter()
formatter.format_transcript(transcript_list)
# Out:
# '[{"text": "So as a final example of divide and conquer, we\\u00a0\\nwill look at a problem called quick select.\\n\\u00a0", "start": 9.92, "duration": 6.0}, {"text": "So selection is the problem of\\u00a0\\nfinding a specific position in\\u00a0\\u00a0", "start": 17.28, "duration": 4.72}, {"text": "a list. So in particular we want to find the\\u00a0\\nkth largest value in a sequence of length n.\\u00a0\\u00a0", "start": 22.0, "duration": 5.76}, {"text": "So of course one way to do this is to sort the\\u00a0\\nlist in descending order, and then the largest\\u00a0\\u00a0", "start": 28.8, "duration": 6.16}, {"text": "value is the first one, the second largest value\\u00a0\\nis the second one and so on, so by just looking at\\u00a0\\u00a0", "start": 34.96, "duration": 4.48}, {"text": "position k in the sorted list in descending\\u00a0\\norder we will get the kth largest value.\\n\\u00a0", "start": 39.44, "duration": 4.4}, {"text": "So since we know we can sort in n log n,\\u00a0\\nthis would mean that the kth largest value,\\u00a0\\u00a0", "start": 44.48, "duration": 5.12}, {"text": "the selection problem of finding the\\u00a0\\nkth largest value also takes n log n.\\u00a0\\u00a0", "start": 49.6, "duration": 3.84}, {"text": "But if we look at some special cases it perhaps\\u00a0\\nsuggests that we could do better. For instance,\\u00a0\\u00a0", "start": 54.8, "duration": 5.28}, {"text": "if we want k equal to 1 then we are just\\u00a0\\nlooking for the largest value in the list\\u00a0\\u00a0", "start": 60.08, "duration": 5.12}, {"text": "and that is just the maximum. And we know\\u00a0\\nthat we can compute the maximum in a list\\u00a0\\u00a0", "start": 65.2, "duration": 4.48}, {"text": "in a single scan so it only takes order\\u00a0\\nn time, it does not take n log n time.\\n\\u00a0", "start": 69.68, "duration": 3.68}, {"text": "Similarly, if k is equal to n, that is, we want\\u00a0\\nthe smallest value in the list, then we can just\\u00a0\\u00a0", "start": 74.16, "duration": 4.96}, {"text": "compute the minimum in a single scan of order\\u00a0\\nn. So the question is can we do this for all k?\\u00a0\\u00a0", "start": 79.12, "duration": 7.04}, {"text": "So if we fix a k, then of course in\\u00a0\\nthe first pass we can find the largest,\\u00a0\\u00a0", "start": 88.32, "duration": 4.56}, {"text": "and then among the remaining in the second\\u00a0\\npass we can find the second largest. \\n\\u00a0", "start": 93.44, "duration": 3.6}, {"text": "So we can make k passes and in order k times n\\u00a0\\ntime, we can always find the kth largest. Now, the\\u00a0\\u00a0", "start": 97.04, "duration": 5.92}, {"text": "problem is that as k becomes large, in particular,\\u00a0\\nif k is like n minus 1 or n by 2 for instance,\\u00a0\\u00a0", "start": 102.96, "duration": 5.6}, {"text": "then this would become order n squared.\\nSo in particular the median is the value in\\u00a0\\u00a0", "start": 108.56, "duration": 5.12}, {"text": "the center of the list so if we sort the list then\\u00a0\\nthe median will be the value at position n by 2.\\u00a0\\u00a0", "start": 113.68, "duration": 5.68}, {"text": "So if we just use this naive thing here then\\u00a0\\nthe time it will take to find the median\\u00a0\\u00a0", "start": 120.64, "duration": 6.64}, {"text": "is n by 2 passes on a list of length\\u00a0\\nn which will be order n squared.\\n\\u00a0", "start": 127.28, "duration": 3.76}, {"text": "Now remember that one thing we had said before is\\u00a0\\nthat if we can actually find the median quickly in\\u00a0\\u00a0", "start": 132.32, "duration": 5.6}, {"text": "order n time, then what we can do is we can take\\u00a0\\nthis list and then find the median as the pivot\\u00a0\\u00a0", "start": 137.92, "duration": 5.92}, {"text": "and then create this lower list and this upper\\u00a0\\nlist which are roughly half because the median\\u00a0\\u00a0", "start": 143.84, "duration": 3.92}, {"text": "will divide it into two parts which are half.\\nAnd if the two are  ...

# %%
import urllib.request
import json

# https://www.youtube.com/watch?v=L1SPxZvjpoM

VIDEO_ID = 'f8dhP521DHI'
url = f"https://www.youtube.com/watch?v={VIDEO_ID}"

with urllib.request.urlopen(url) as response:
    response_text = response.read()
    print(response_text)
    data = json.loads(response_text.decode())
    video_title = data["title"]
    print(f"Video Title: {video_title}")
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="VG-9HW5o9VFCgdndjxLGhg">window.WIZ_global_data = {"AfY8Hf":true,"HiPsbb":0,"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20251221.10_p0","fPDxwd":[],"hsFLT":"%.@.null,1000,2]","iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"772657768":true,"513659523":false,"568333945":true,"1331761403":false,"651175828":false,"722764542":false,"748402145":false,"748402146":false,"748402147":true,"824648567":true,"824656860":false,"333098724":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="VG-9HW5o9VFCgdndjxLGhg">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20251222.04.00\');</script><script nonce="VG-9HW5o9VFCgdndjxLGhg">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};\nvar combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn=combinedLineAndColumn+(":"+err["columnNumber"]);var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\\/\\/www.youtube.com\\//g,"");if(replaced.match(/https?:\\/\\/[^/]+\\//))thirdPartyScript=\ntrue;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];var key;for(key in values){var value=\nvalues[key];if(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};\n(function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);var i=0;var n=void 0;for(;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e){throw new Error("Pol ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[14], line 12
#      10 response_text = response.read()
#      11 print(response_text)
# ---> 12 data = json.loads(response_text.decode())
#      13 video_title = data["title"]
#      14 print(f"Video Title: {video_title}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get(url)
html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')
title_tag = soup.find('meta', property='og:title')

if title_tag:
    video_title = title_tag['content']
    print(f"Video Title: {video_title}")
else:
    print("Title not found.")
# Out:
# Video Title: W8L5_Divide and Conquer  Quick Select
